# %% [markdown]
# ## <p style="color:green;">Q.1 Using keys and indexing, grab the 'hello' from the following dictionaries:</p>
# >d = {'k1':{'k2':'hello'}}

# %%
# Answer here 
d = {'k1':{'k2':'hello'}}
d['k1']['k2']
# Out:
# 'hello'

# %% [markdown]
# ## <p style="color:orange;">Q.2 Using keys and indexing, grab the 'hello' from the following dictionaries:</p>
# > d = {'k1':[{'nest_key':['this is deep',['hello']]}]}

# %%
# Answer here 
d2 = {'k1':[{'nest_key':['this is deep',['hello']]}]}
list(d2['k1'][0].values())[0][1][0]
# Out:
# 'hello'

# %% [markdown]
# ## <p style="color:red;">Q.3 Using keys and indexing, grab the 'hello' from the following dictionaries:</p>
# d = {'k1':[1,2,{'k2':['this is tricky',{'tough':[1,2,['hello']]}]}]}

# %%
# Answer here 
d3 = {'k1':[1,2,{'k2':['this is tricky',{'tough':[1,2,['hello']]}]}]}
list(list(d3['k1'][2].values())[0][1].values())[0][2][0]
# Out:
# 'hello'

# %% [markdown]
# ## <p style="color:green;">Q.4 Write a Python script to add a key to a dictionary.</p>
# > Sample Dictionary : {0: 10, 1: 20}
#
# > Expected Result : {0: 10, 1: 20, 2: 30}

# %%
# Answer here 
d4= {0: 10, 1: 20}
d4[2]=30
d4
# Out:
# {0: 10, 1: 20, 2: 30}

# %% [markdown]
# ## <p style="color:green;">Q.5 Write a Python program to sum all the items in a dictionary.</p>

# %%
# Answer here 
sum(list(d4.values()))
# Out:
# 60

# %% [markdown]
# ## <p style="color:green;">Q.6 Handle the exception thrown by the code below by using <code>try</code> and <code>except</code> blocks.</p>

# %%
# Answer here 
try:
    for i in ['a','b','c']:
        print(i**2)
except Exception as e:
    print(e)
# Out:
# unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %% [markdown]
# ## <p style="color:green;">Q.7 Handle the exception thrown by the code below by using <code>try</code> and <code>except</code> blocks. Then use a <code>finally</code> block to print 'All Done.'</p>

# %%
# Answer here 
try:
    x = 5
    y = 0
    z = x/y
except Exception as e:
    print(e)
finally:
    print('All Done')
# Out:
# division by zero
# All Done

# %% [markdown]
# ## <p style="color:green;">Q.8 Write a function that asks for an integer and prints the square of it. Use a <code>while</code> loop with a <code>try</code>, <code>except</code>, <code>else</code> block to account for incorrect inputs.</p>

# %%
# Answer here 
def ask()-> int:
    """Accept an integer number as input and return square of that number"""
    while True:
        try:
            num = int(input('Insert an integer number: '))
        except Exception as e:
            print('Insert correct data type -Integer Only-')
        else: 
            break
    print(num**2)

# %%
ask()
# Out:
# Insert correct data type -Integer Only-
# Insert correct data type -Integer Only-
# Insert correct data type -Integer Only-
# 81
